# %%
#Program to count the number of sentences in a given text
# s="How are you. I am fine."
# c=0
# for ch in s:
#     if ch==".":
#         c=c+1
# print("The number of sentences:",c)
# #Program to count the number of sentences in a given text
# s="How are you. I am fine."
# c=0
# txt=s.split(".")
# for i in txt:
#     if(len(i)>0):
#         c=c+1
# print("The number of sentences:",c)
# #Code to find number of words in a text file
# s="How are you. I am fine."
# print("The number of words in the text",len(s.split()))
# '''
# x="""I have four apples.
# All apples are nutricious. These apples are tasty."""
# t=x.replace("apple","banana").replace("are","if")
# print(t)

def count_sentences(text):
    """Counts the number of sentences in a given text.

    Args:
        text: The input text string.

    Returns:
        The number of sentences in the text.
    """
    sentence_count = 0
    for char in text:
        if char == '.':
            sentence_count += 1
    return sentence_count


def count_sentences_split(text):
    """Counts the number of sentences in a given text using split.

    Args:
      text: The input text string.

    Returns:
      The number of sentences in the text.
    """
    sentences = text.split('.')
    count = 0
    for sentence in sentences:
        if len(sentence) > 0:
            count += 1
    return count


def count_words(text):
    """Counts the number of words in a given text.

    Args:
      text: The input text string.

    Returns:
      The number of words in the text.
    """
    return len(text.split())


# Example usage
text = "How are you. I am fine."
print("Number of sentences (method 1):", count_sentences(text))
print("Number of sentences (method 2):", count_sentences_split(text))
print("Number of words:", count_words(text))

# Example with multiple lines and replacements
x = """I have four apples.
All apples are nutricious. These apples are tasty."""
t = x.replace("apple", "banana").replace("are", "if")
t
# Out:
# Number of sentences (method 1): 2
# Number of sentences (method 2): 2
# Number of words: 6
# 'I have four bananas. \nAll bananas if nutricious. These bananas if tasty.'
